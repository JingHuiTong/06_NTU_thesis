# %%
import os,glob
import pandas as pd

# %%
path = '/Volumes/home/Research/STEP/02_Station_result_csv'

# %%
for csvpath in glob.glob(f'{path}/*SKS*_classify_220913/*AKH*v2.csv'):
    print(csvpath)
    df = pd.read_csv(csvpath)
    dff = df[df['Null']==False][df['Pick']==True][df['Quality']=='Poor']
    print(dff)
# Out:
# /Volumes/home/Research/STEP/02_Station_result_csv/2010-2020_SKS_classify_220913/GO.AKH_split_result_v2.csv
#               Event   Ev_lat    Ev_lon   Depth  Mag Phase  SCPhi  SCPhi_std  \
# 7   20120604_004516   5.2944  -82.6322   15.00  6.3   SKS  20.79      44.75
# 10  20120728_200359  -4.6540  153.1678   58.80  6.5   SKS  59.09       6.50
# 25  20140302_093754  12.5888  -87.7040   70.40  6.2   SKS -34.16      44.75
# 26  20140311_220312  -3.1902  148.6003   16.30  6.1   SKS  70.13       7.50
# 28  20140315_235132  -5.6717  -80.9351   26.50  6.3   SKS -86.85      44.75
# 33  20140327_034944 -12.1378  166.6228  109.70  6.0   SKS  -3.65      44.75
# 68  20140412_201438 -11.2581  162.1387   15.30  7.6   SKS  68.98      12.25
# 77  20171024_104747  -7.2364  123.0401  549.19  6.7   SKS -87.82       2.00
# 79  20180226_133453  -2.7629  126.7272    9.91  6.1   SKS -88.60      44.75
#
#     SCdt  SCdt_std  ...  RCPhi_std  RCdt  RCdt_std   SNRQ   SNRT   Null  \
# ...

# %%
dff
# Out:
#               Event   Ev_lat    Ev_lon   Depth  Mag Phase  SCPhi  SCPhi_std  \
# 7   20120604_004516   5.2944  -82.6322   15.00  6.3   SKS  20.79      44.75
# 10  20120728_200359  -4.6540  153.1678   58.80  6.5   SKS  59.09       6.50
# 25  20140302_093754  12.5888  -87.7040   70.40  6.2   SKS -34.16      44.75
# 26  20140311_220312  -3.1902  148.6003   16.30  6.1   SKS  70.13       7.50
# 28  20140315_235132  -5.6717  -80.9351   26.50  6.3   SKS -86.85      44.75
# 33  20140327_034944 -12.1378  166.6228  109.70  6.0   SKS  -3.65      44.75
# 68  20140412_201438 -11.2581  162.1387   15.30  7.6   SKS  68.98      12.25
# 77  20171024_104747  -7.2364  123.0401  549.19  6.7   SKS -87.82       2.00
# 79  20180226_133453  -2.7629  126.7272    9.91  6.1   SKS -88.60      44.75
#
#     SCdt  SCdt_std  ...  RCPhi_std  RCdt  RCdt_std   SNRQ   SNRT   Null  \
# 7    2.2      0.98  ...      44.75   0.5      0.98   6.55   2.20  False
# ...
